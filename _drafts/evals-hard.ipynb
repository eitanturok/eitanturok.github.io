# %% [markdown]
# I don't think people understand why evals are so hard. Simply gaurnetting correntess and implementing a benchmark should be pretty staraightfroward. So here isa list of examples of hwere evals get tricky.

# %% [markdown]
# <blockquote class="twitter-tweet"><p lang="en" dir="ltr">what the actual fuck is even happening<br><br>reminder: scores are ~80 (high), ~73 (med), ~68 (low)<br><br>dunno what those providers even do 🤦‍♂️ <a href="https://t.co/vJtBYHv79g">https://t.co/vJtBYHv79g</a> <a href="https://t.co/75lrQMKd8F">pic.twitter.com/75lrQMKd8F</a></p>&mdash; Xeophon @ NeurIPS 🇺🇸 (@xeophon_) <a href="https://twitter.com/xeophon_/status/1994102233839833097?ref_src=twsrc%5Etfw">November 27, 2025</a></blockquote> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>

# %% [markdown]
# <blockquote class="twitter-tweet"><p lang="en" dir="ltr">sampling noise isn&#39;t the issue here and wouldn&#39;t explain 10% on benches of this size, the problem is that there literally aren&#39;t standard implementations that everyone uses<br><br>you&#39;d see a gap with avg@1000<br><br>&quot;GLM GPQA&quot; and &quot;gpt-oss GPQA&quot; are fundamentally different evals</p>&mdash; will brown (@willccbb) <a href="https://twitter.com/willccbb/status/1994309518751134061?ref_src=twsrc%5Etfw">November 28, 2025</a></blockquote> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>

# %% [markdown]
# <blockquote class="twitter-tweet"><p lang="en" dir="ltr">there are no standard implementations!!!<br><br>we would use them if they existed <br><br>there is an official gpt-oss GPQA, and an official GLM GPQA, and their implementations are significantly different<br><br>our claim is not that either of those are “wrong”, just that they’re different, and…</p>&mdash; will brown (@willccbb) <a href="https://twitter.com/willccbb/status/1994316008694432046?ref_src=twsrc%5Etfw">November 28, 2025</a></blockquote> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
